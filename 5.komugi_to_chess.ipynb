# %% [markdown]
# # 小麦とチェス盤問題
#
# 8×8マスのチェス盤の上に、小麦の粒を1, 2, 4と順番に置いていくと最終的な小麦の数はどのようになるかという問題です。
#
#
# 少ないマスで考える
#
# まずは4マスの板に小麦の粒を並べていくことを考えます。配列（リスト）の1つの要素を1つのマスに見立てています。
#
#
# Pythonのリストとfor文を使い次のように作ることができます。
#
#
# 《サンプルコード》
#
#
# 1
# 2
# 3
# 4
# 5
# n_squares = 4
# small_board_list = [1]
#
# for _ in range(n_squares - 1):
#
#     small_board_list.append(2*small_board_list[-1])
#
# print("4マスの板に小麦を並べる（リスト）：{}".format(small_board_list))
#
# このリストにnp.array()を使うことで、ndarrayを作成することができます。
#
#
# 1
# 2
# 3
# 4
# import numpy as np
# small_board_ndarray = np.array(small_board_list)
#
# print("4マスの板に小麦を並べる（ndarray）：{}".format(small_board_ndarray))
#
# ## 【問題1】2×2マスのチェス盤の小麦の数
#
# 2×2マスのチェス盤をndarrayによって表現し、各マスの小麦の数を計算してください。
#
# 左上のマスに小麦を1つ置いた後、その右が2つ、左下が4つ、右下が8つという風に進みます。
#
#
# サンプルコードで作成したndarrayのshapeの変形を行ってください。

# %%
n_squares = 4
small_board_list = [1]
for _ in range(n_squares - 1):
    small_board_list.append(2*small_board_list[-1])
print("4マスの板に小麦を並べる（リスト）：{}".format(small_board_list))

import numpy as np

small_board_ndarray = np.array(small_board_list)

# 回答① reshapeで形を変更
print("4マスの板に小麦を並べる（ndarray）：{}".format(small_board_ndarray.reshape(2, 2)))
# Out:
# 4マスの板に小麦を並べる（リスト）：[1, 2, 4, 8]
# 4マスの板に小麦を並べる（ndarray）：[[1 2]
#  [4 8]]

# %% [markdown]
# ## 8×8マスのチェス盤
#
# ## 【問題2】n×mマスへの拡張
# n×mマスのチェス盤の小麦の数を記したndarrayを返す関数を作成してください。
#
# そして、この関数を使い8×8マスのチェス盤の小麦の数を求めてください。

# %%
import numpy as np

def calc(n):
    '''
    入力した数字（０の軸と１の軸の合計数）のマスのチェス版の小麦数を計算する関数
    Paramenters
    ----------
    n: int
        マスの０軸と１軸
    ----------
    return
        small_board_ndarray
        リストに代入されたマスごとに倍がけされる小麦の数
    '''
    x = n
    sample_list = [1]
    
    for _ in range(x - 1):
        sample_list.append(2*sample_list[-1])
    
    small_board_ndarray = np.array(sample_list)

    return small_board_ndarray
    
print("8×8マスのチェス盤に並ぶ小麦は{}です".format(calc(64)))
print(sum(calc(64)))
# Out:
# 8×8マスのチェス盤に並ぶ小麦は[1.00000000e+00 2.00000000e+00 4.00000000e+00 8.00000000e+00
#  1.60000000e+01 3.20000000e+01 6.40000000e+01 1.28000000e+02
#  2.56000000e+02 5.12000000e+02 1.02400000e+03 2.04800000e+03
#  4.09600000e+03 8.19200000e+03 1.63840000e+04 3.27680000e+04
#  6.55360000e+04 1.31072000e+05 2.62144000e+05 5.24288000e+05
#  1.04857600e+06 2.09715200e+06 4.19430400e+06 8.38860800e+06
#  1.67772160e+07 3.35544320e+07 6.71088640e+07 1.34217728e+08
#  2.68435456e+08 5.36870912e+08 1.07374182e+09 2.14748365e+09
#  4.29496730e+09 8.58993459e+09 1.71798692e+10 3.43597384e+10
#  6.87194767e+10 1.37438953e+11 2.74877907e+11 5.49755814e+11
#  1.09951163e+12 2.19902326e+12 4.39804651e+12 8.79609302e+12
#  1.75921860e+13 3.51843721e+13 7.03687442e+13 1.40737488e+14
#  2.81474977e+14 5.62949953e+14 1.12589991e+15 2.25179981e+15
#  4.50359963e+15 9.00719925e+15 1.80143985e+16 3.60287970e+16
#  7.20575940e+16 1.44115188e+17 2.88230376e+17 5.76460752e+17
# ...

# %% [markdown]
# ## 【問題3】小麦の数の合計
# 8×8マスのチェス盤の小麦の数の合計を求めてください。また、各列の平均を求め、それを棒グラフで可視化してください。
#
#
# 棒グラフはサンプルコードを用意しています。
#
#
# ** 《棒グラフのサンプルコード》 **
#
# import matplotlib.pyplot as plt
#
# %matplotlib inline
#
# plt.xlabel("column")
#
# plt.ylabel("number")
#
# plt.title("number in each column")
#
# plt.bar(np.arange(1,4), np.array([1, 2, 3]))
#
# plt.show()

# %%
import numpy as np

def calc(n):
    '''
    入力した数字（０の軸と１の軸の合計数）のマスのチェス版の小麦数を計算する関数
    Paramenters
    ----------
    n: int
        マスの０軸と１軸
    ----------
    return
        small_board_ndarray
        リストに代入されたマスごとに倍がけされる小麦の数
    '''
    x = n
    sample_list = [1]
    
    for _ in range(x - 1):
        sample_list.append(2*sample_list[-1])
    
    small_board_ndarray = np.array(sample_list)

    return small_board_ndarray

small_board_ndarray = calc(64)
total = sum(small_board_ndarray)
average = small_board_ndarray.mean(axis=0)

# 回答
print("8×8マスのチェス盤に並ぶ小麦の合計数は{}です".format(total))

# print(small_board_ndarray.reshape(8,  8))

print("０軸の平均は{}です".format(average))

import matplotlib.pyplot as plt

# %matplotlib inline

height = np.array(small_board_ndarray)


import matplotlib.pyplot as plt

# %matplotlib inline

plt.xlabel("total")

plt.ylabel("average")

plt.title("8 * 8 chess")

plt.bar(np.arange(1,4), np.array([1, 2, 3]))

plt.show()
# Out:
# 8×8マスのチェス盤に並ぶ小麦の合計数は1.8446744073709552e+19です
# ０軸の平均は2.8823037615171174e+17です

# %% [markdown]
# ## 【問題4】小麦の数のヒートマップ
#
# 8×8マスのチェス盤の小麦の数をヒートマップとして可視化してください。
#
#
# ヒートマップはサンプルコードを用意しています。
#
#
# **《ヒートマップのサンプルコード》**
#
#
# 4行2列の配列のヒートマップです。値が小さいところが紫、大きいところが黄色になっています。
#
# plt.xlabel("column")
#
# plt.ylabel("row")
#
# plt.title("heatmap")
#
# plt.pcolor(np.array([0, 1, 3, 5, 7, 9, 11, 13]).reshape(4, 2))
#
# plt.show()

# %%
import numpy as np

def calc(n):
    '''
    入力した数字（０の軸と１の軸の合計数）のマスのチェス版の小麦数を計算する関数
    Paramenters
    ----------
    n: int
        マスの０軸と１軸
    ----------
    return
        small_board_ndarray
        リストに代入されたマスごとに倍がけされる小麦の数
    '''
    x = n
    sample_list = [1]
    
    for _ in range(x - 1):
        sample_list.append(2*sample_list[-1])
    
    small_board_ndarray = np.array(sample_list)

    return small_board_ndarray

small_board_ndarray = calc(64)
total = sum(small_board_ndarray)
average = small_board_ndarray.mean(axis=0)

# 回答
print(small_board_ndarray.reshape(8,  8))

# 回答（グラフ）
import matplotlib.pyplot as plt

plt.xlabel("column")

plt.ylabel("row")

plt.title("heatmap")

plt.pcolor(np.array(small_board_ndarray).reshape(8, 8))

plt.show()
# Out:
# [[1.00000000e+00 2.00000000e+00 4.00000000e+00 8.00000000e+00
#   1.60000000e+01 3.20000000e+01 6.40000000e+01 1.28000000e+02]
#  [2.56000000e+02 5.12000000e+02 1.02400000e+03 2.04800000e+03
#   4.09600000e+03 8.19200000e+03 1.63840000e+04 3.27680000e+04]
#  [6.55360000e+04 1.31072000e+05 2.62144000e+05 5.24288000e+05
#   1.04857600e+06 2.09715200e+06 4.19430400e+06 8.38860800e+06]
#  [1.67772160e+07 3.35544320e+07 6.71088640e+07 1.34217728e+08
#   2.68435456e+08 5.36870912e+08 1.07374182e+09 2.14748365e+09]
#  [4.29496730e+09 8.58993459e+09 1.71798692e+10 3.43597384e+10
#   6.87194767e+10 1.37438953e+11 2.74877907e+11 5.49755814e+11]
#  [1.09951163e+12 2.19902326e+12 4.39804651e+12 8.79609302e+12
#   1.75921860e+13 3.51843721e+13 7.03687442e+13 1.40737488e+14]
#  [2.81474977e+14 5.62949953e+14 1.12589991e+15 2.25179981e+15
#   4.50359963e+15 9.00719925e+15 1.80143985e+16 3.60287970e+16]
#  [7.20575940e+16 1.44115188e+17 2.88230376e+17 5.76460752e+17
# ...

# %% [markdown]
# アメリカの発明家レイ・カーツワイルはこの逸話を引用し、「チェス盤の後半」というフレーズを作りました。
#
# 技術の進歩ははじめの内は社会に対して目立った影響が感じられなくとも、倍に倍にと進んでいくと、
#
# チェス盤の後半にさしかかったころから、急激な変化を起こすということを伝えています。
#
#
# ## 【問題5】後半は前半の何倍か
# チェス盤の後半にある小麦の数は前半にある小麦の数の何倍かを求めてください。
#
# 前半とは配列の0から3行目、後半は4から7行目です。

# %%
# 前半（０から３行目まで）の平均と後半（４から７行目まで）の平均を出して、何倍になっているか確認する

import numpy as np

def calc(n):
    '''
    入力した数字（０の軸と１の軸の合計数）のマスのチェス版の小麦数を計算する関数
    Paramenters
    ----------
    n: int
        マスの０軸と１軸
    ----------
    return
        small_board_ndarray
        リストに代入されたマスごとに倍がけされる小麦の数
    '''
    x = n
    sample_list = [1]
    
    for _ in range(x - 1):
        sample_list.append(2*sample_list[-1])
    
    small_board_ndarray = np.array(sample_list)

    return small_board_ndarray

small_board_ndarray = calc(64)
total = sum(small_board_ndarray)

# ８*８マスにする
small_board_ndarray = small_board_ndarray.reshape(8,  8)
# 前半の配列を取り出す
first_half = small_board_ndarray[0,3]
# 後半の配列を取り出す
latter_half = small_board_ndarray[4,7]

# 前半の平均
print("前半の平均は{}です".format(first_half))
# 後半の平均
print("後半の平均は{}です".format(latter_half))

# 後半の数字を前半の数字で割って何倍か算出
double_num = latter_half / first_half

# 回答
print("チェス盤の後半には、前半の{}倍もの数の小麦があります。".format(double_num))
# Out:
# 前半の平均は8.0です
# 後半の平均は549755813888.0です
# チェス盤の後半には、前半の68719476736.0倍もの数の小麦があります。

# %% [markdown]
# 他の計算方法
#
# はじめのサンプルコードではPythonのリストとfor文を使っていましたが、他の方法も考えられます。
#
#
# ndarrayのnp.append()とfor文を使うと次のように作ることができます。
#
#
# **《サンプルコード（np.append()）》**
#
# n_squares = 4
# small_board_ndarray = np.array([1])
# for _ in range(n_squares - 1):
#     small_board_ndarray = np.append(small_board_ndarray, 2*small_board_ndarray[-1])
# print("4マスの板に小麦を並べる（ndarray）：{}".format(small_board_ndarray))
#
# ブロードキャストを活用することで、次のようにも作ることができます。
#
#
# **《サンプルコード（ブロードキャスト）》**
#
# n_squares = 4
#
#
# indices_of_squares = np.arange(n_squares)
#
#
# small_board_ndarray = 2**indices_of_squares
#
#
# print("4マスの板に小麦を並べる（ndarray）：{}".format(small_board_ndarray))
#
# 《numpyのブロードキャスト》
# 概要：
# pythonのnumpyには「ブロードキャスト」という仕様があります。
#
# これはnumpyのベクトル・行列計算において、２入力間で次元数やサイズの小さい方を複製してデータを自動で統一する機能です。
#
# ブロードキャストを使うメリットとして、
#
# ①コードが短くなるため、実行速度が早くなる。
#
# ②メモリの使用量を節約できる。の２点が主に挙げられます。
#
#
# 例：
#
# import numpy as np
# a = np.array([0,1,2])
# #ブロードキャストを使わない場合
# b = np.array([5,5,5])
# print(a + b)  # Out: [5,6,7]
#
# #ブロードキャストを使う場合
#
# print(a + 5)  # Out: [5,6,7]　※5が自動的に(1,3)の行列([5,5,5])に変換されている
#
# ブロードキャストの詳細や変換ルールについては公式リファレンスを参照してみてください。
#
#
# ndarrayの型
# なお、これらの方法で64マスの小麦の数を調べたい場合、型の問題が出てきます。
#
#
# n_squares = 64
#
#
# board_ndarray = np.array([1])
#
# for _ in range(n_squares - 1):
#
#     board_ndarray = np.append(board_ndarray, 2*board_ndarray[-1])
#
# print("最後のマスの小麦の数：{}".format(board_ndarray[-1])) # -9223372036854775808
#
#
# n_squares = 64
#
# indices_of_squares = np.arange(n_squares)
#
# board_ndarray = 2**indices_of_squares
#
# print("最後のマスの小麦の数：{}".format(board_ndarray[-1])) # -9223372036854775808
#
#
# 最後の64マス目が-9223372036854775808と負の数になり明らかに間違っています。
#
# このndarrayの型を見ると、次のように int64 です。
#
#
# print(board_ndarray.dtype) # int64
#
# int64は64ビットの整数型で、-9,223,372,036,854,775,808 ~ 9,223,372,036,854,775,807 の範囲の整数値しか扱えないことを示しています。
#
# この値は -2の64乗から2の64乗-1 です。そのため、2の64乗になる64マス目の値が範囲外となり、負の値として出てきてしまっているのです。
#
#
# Pythonの整数型（int）にはこのような制限がありませんが、ndarrayは高速な計算が行える反面、
#
# こういった制約があり、型で扱える範囲を意識しておく必要があります。
#
#
# 今回は正の値しか利用しないため、 uint64 を使用することで解決します。
#
# 0 ~ 18,446,744,073,709,551,615 を扱うことができます。astypeメソッドを使うことで型を変換できるので、
#
# 累乗の計算前にこれを使いndarrayをuint64型にしておきます。
#
#
# n_squares = 64
# indices_of_squares = np.arange(n_squares).astype(np.uint64)
# board_ndarray = 2**indices_of_squares
# print("最後のマスの小麦の数：{}".format(board_ndarray[-1])) # 9223372036854775808
#
# これで正しく計算ができました。
#
#
#
#
# 【問題6】他の計算方法によるn×mマスへの拡張
# 問題2と同様の「n×mマスのチェス盤の小麦の数を記したndarrayを返す関数」を、np.append()を使ったものと、ブロードキャストを使ったもので新たに作成してください。
#
#
# それらの関数を使い8×8マスのチェス盤の小麦の数を再び求めてください。
#
# ## 【問題6】他の計算方法によるn×mマスへの拡張
#
# 問題2と同様の「n×mマスのチェス盤の小麦の数を記したndarrayを返す関数」を、
#
# np.append()を使ったものと、ブロードキャストを使ったもので新たに作成してください。
#
#
# それらの関数を使い8×8マスのチェス盤の小麦の数を再び求めてください。

# %%
# np.append()を使って求める

import numpy as np

def calc(n):
    '''
    入力した数字（０の軸と１の軸の合計数）のマスのチェス版の小麦数を計算する関数
    Paramenters
    ----------
    n: int
        マスの０軸と１軸
    ----------
    return
        small_board_ndarray
        リストに代入されたマスごとに倍がけされる小麦の数
    '''
    
# print("4マスの板に小麦を並べる（ndarray）：{}".format(small_board_ndarray))
 
    small_board_ndarray = [1]
    
    for _ in range(n - 1):
        small_board_ndarray = np.append(small_board_ndarray, 2*small_board_ndarray[-1])
    
#     small_board_ndarray = np.array([1, 64])

    return small_board_ndarray

total_sum = calc(64)

print("8×8マスのチェス盤に並ぶ小麦は{}です（ndarray）".format(sum(total_sum).astype(np.uint64)))
# Out:
# 8×8マスのチェス盤に並ぶ小麦は18446744073709551615です（ndarray）
# /Users/summitlama/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:23: RuntimeWarning: overflow encountered in long_scalars

# %%
# ブロードキャストを使って求める

import numpy as np

def calc(n):
    '''
    入力した数字（０の軸と１の軸の合計数）のマスのチェス版の小麦数を計算する関数
    Paramenters
    ----------
    n: int
        マスの０軸と１軸
    ----------
    return
        small_board_ndarray
        リストに代入されたマスごとに倍がけされる小麦の数
    '''
 
    indices_of_squares =  np.arange(n).astype(np.uint64)
    
    small_board_ndarray = 2**indices_of_squares

    return small_board_ndarray

total_sum = calc(64)

# 回答
print("8×8マスのチェス盤に並ぶ小麦は{}です（ブロードキャスト）".format(sum(total_sum)))
# Out:
# 8×8マスのチェス盤に並ぶ小麦は1.8446744073709552e+19です（ブロードキャスト）

# %% [markdown]
# ## 【問題7】計算時間の比較
#
# 3種類の方法を見てきました。それぞれの計算時間をJupyter Notebookの%%timeitを用いて計測し、比較と考察を行ってください。
#
#
# %%timeitはセル内のコードを複数回実行し、その平均実行時間を出力する働きをします。

# %%
# %%timeit

# 一種類目 For文
import numpy as np

def calc(n):
    
    x = n
    sample_list = [1]
    
    for _ in range(x - 1):
        sample_list.append(2*sample_list[-1])
    
    small_board_ndarray = np.array(sample_list)

    return small_board_ndarray
# Out:
# 164 ns ± 1 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %%timeit
# 二種類目 np.append()

import numpy as np

def calc(n):
 
    small_board_ndarray = [1]
    
    for _ in range(n - 1):
        small_board_ndarray = np.append(small_board_ndarray, 2*small_board_ndarray[-1])
    
    return small_board_ndarray

total_sum = calc(64)
# Out:
# /Users/summitlama/.pyenv/versions/anaconda3-5.1.0/lib/python3.6/site-packages/ipykernel_launcher.py:10: RuntimeWarning: overflow encountered in long_scalars
#   # Remove the CWD from sys.path while we load stuff.
# 221 µs ± 6.05 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
# %%timeit

# 三種類目　ブロードキャスト

import numpy as np

def calc(n):

    indices_of_squares =  np.arange(n).astype(np.uint64)
    
    small_board_ndarray = 2**indices_of_squares

    return small_board_ndarray

total_sum = calc(64)
# Out:
# 2.73 µs ± 83.7 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %% [markdown]
# 【問題7】計算時間の比較
# np.append() <　For文 < ブロードキャスト
# 計算時間は上記の順番でした。
#
# 文法のシンプルさから考えてもブロードキャストが一番使い勝手が良いと考えました。
